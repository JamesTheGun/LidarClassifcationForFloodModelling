# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
#Set root correctly...
os.chdir(r"C:\Users\jamed\Documents\repos\lidar_2\LidarClassifcationForFloodModelling")

# %%
from RandLANetImplementation.data import modelData

# %%
model_data = modelData()

# %%
model_data.new_split()
# Out:
# tensor([   12956,    12957,    12958,  ..., 18694886, 18694887, 18694888])
# tensor([  21843,   21844,   21845,  ..., 6163672, 6163673, 6163674])
# <class 'torch.Tensor'>

# %%
model_data.next_fold()
# Out:
# tensor([ 6867397,  6867398,  6867399,  ..., 10869187, 10869188, 10869808])

# %%
from RandLANetImplementation.modules import random_sample, get_knn_points
tensor_downsampled = random_sample(model_data.get_folds[0], 0.01)
points_withs_ns = get_knn_points(tensor_downsampled, model_data.test_set, 1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from RandLANetImplementation.modules import random_sample, get_knn_points
# ----> 2 tensor_downsampled = random_sample(model_data.data(model_data.folds[0]), 0.01)
#       3 points_withs_ns = get_knn_points(tensor_downsampled, model_data.test_set, 1000)
#
# TypeError: 'DataFrame' object is not callable

# %%
points_withs_ns
# Out:
# tensor([[[-1.4123e+05,  1.1336e+05,  1.6190e+03,  ...,  1.1000e+01,
#            4.5613e+05,  0.0000e+00],
#          [-1.4125e+05,  1.1330e+05,  1.6630e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.4119e+05,  1.1330e+05,  1.7030e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          ...,
#          [-1.4209e+05,  1.1361e+05,  1.6120e+03,  ...,  1.1000e+01,
#            4.5613e+05,  0.0000e+00],
#          [-1.4207e+05,  1.1304e+05,  1.6200e+03,  ...,  1.1000e+01,
#            4.5613e+05,  0.0000e+00],
#          [-1.4092e+05,  1.1252e+05,  1.6610e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00]],
#
#         [[-1.7792e+05,  1.6699e+05,  1.2330e+03,  ...,  1.0000e+01,
#            4.5544e+05,  0.0000e+00],
#          [-1.7785e+05,  1.6699e+05,  1.2160e+03,  ...,  1.0000e+01,
#            4.5544e+05,  0.0000e+00],
#          [-1.7779e+05,  1.6699e+05,  1.2300e+03,  ...,  1.0000e+01,
#            4.5544e+05,  0.0000e+00],
#          ...,
#          [-1.7669e+05,  1.6729e+05,  1.2300e+03,  ...,  1.0000e+01,
#            4.5544e+05,  0.0000e+00],
#          [-1.7676e+05,  1.6750e+05,  1.2260e+03,  ...,  1.0000e+01,
#            4.5544e+05,  0.0000e+00],
#          [-1.7876e+05,  1.6779e+05,  1.2360e+03,  ...,  1.0000e+01,
#            4.5544e+05,  0.0000e+00]],
#
#         [[-1.6019e+05,  1.2168e+05,  1.4090e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.6012e+05,  1.2168e+05,  1.4090e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.6014e+05,  1.2161e+05,  1.4070e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          ...,
#          [-1.5958e+05,  1.2280e+05,  1.4220e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.6137e+05,  1.2174e+05,  1.3980e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.5890e+05,  1.2193e+05,  1.4290e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00]],
#
#         ...,
#
#         [[-1.4893e+05,  1.0861e+05,  1.5610e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.4894e+05,  1.0861e+05,  1.5570e+03,  ...,  1.1000e+01,
#            4.5613e+05,  0.0000e+00],
#          [-1.4900e+05,  1.0861e+05,  1.5610e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          ...,
#          [-1.4958e+05,  1.0784e+05,  1.5530e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.4817e+05,  1.0795e+05,  1.6530e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.4991e+05,  1.0886e+05,  1.5700e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00]],
#
#         [[-1.2736e+05,  1.4581e+05,  2.9000e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.2731e+05,  1.4580e+05,  2.9560e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.2724e+05,  1.4580e+05,  2.9690e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          ...,
#          [-1.2647e+05,  1.4616e+05,  2.9800e+03,  ...,  1.1000e+01,
#            4.5612e+05,  0.0000e+00],
#          [-1.2811e+05,  1.4535e+05,  2.7770e+03,  ...,  1.1000e+01,
#            4.5612e+05,  0.0000e+00],
#          [-1.2710e+05,  1.4491e+05,  2.8610e+03,  ...,  1.1000e+01,
#            4.5612e+05,  0.0000e+00]],
#
#         [[-1.8949e+05,  1.1106e+05,  1.3610e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.8947e+05,  1.1112e+05,  1.3620e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.8955e+05,  1.1115e+05,  1.3640e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          ...,
#          [-1.8957e+05,  1.0990e+05,  1.3720e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.8837e+05,  1.1059e+05,  1.5220e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00],
#          [-1.8829e+05,  1.1143e+05,  1.3480e+03,  ...,  1.0000e+01,
#            4.5543e+05,  0.0000e+00]]])
